# %%
# !pip install accelerate -U
# !pip install rouge
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.32.1)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.5)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.16.0)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
# !git clone https://github.com/ryanzhumich/AESLC
# Out:
# Cloning into 'AESLC'...
# remote: Enumerating objects: 17469, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 17469 (delta 1), reused 0 (delta 0), pack-reused 17461
# Receiving objects: 100% (17469/17469), 7.36 MiB | 12.73 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from transformers import GPT2LMHeadModel, GPT2Tokenizer, Trainer, TrainingArguments
import torch
from torch.utils.data import Dataset, DataLoader

# Ensure NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def preprocess_text(text):
    # Tokenize text
    tokens = word_tokenize(text.lower())

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words and word.isalnum()]

    # Lemmatize tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    # Join tokens back into a string
    preprocessed_text = ' '.join(tokens)

    return preprocessed_text

# %%
def sanitize_subject(subject):
    # Remove special characters from the subject
    return re.sub(r'[^a-zA-Z0-9\s]', '', subject)

# %%
import os
import re

def load_emails_and_subjects(emails_directory):
    emails = []
    subjects = []

    for filename in os.listdir(emails_directory):
        file_path = os.path.join(emails_directory, filename)

        with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
            email_text = file.read()

            # Extract subject from email body using regex
            match = re.search(r'@subject\s+(.*)', email_text, re.IGNORECASE | re.DOTALL)

            if match:
                subject = match.group(1).strip()
                email_body = re.sub(r'@subject\n(.+)\n', '', email_text).strip()
                preprocessed_email = preprocess_text(email_body)

                emails.append(preprocessed_email)
                subjects.append(subject)

    return emails, subjects

# %%
train_emails, tain_subjects = load_emails_and_subjects('/content/AESLC/enron_subject_line/train')
dev_emails, dev_subjects = load_emails_and_subjects('/content/AESLC/enron_subject_line/dev')
test_emails, test_subjects = load_emails_and_subjects('/content/AESLC/enron_subject_line/test')

# %%
import pandas as pd

# %%
train_data = pd.DataFrame({'subject_line': tain_subjects, 'email_body': train_emails})
dev_data = pd.DataFrame({'subject_line': dev_subjects, 'email_body': dev_emails})
test_data = pd.DataFrame({'subject_line': test_subjects, 'email_body': test_emails})

# %%
train_data.head()
# Out:
#                    subject_line  \
# 0              Bank of Montreal
# 1       Override letter for ABB
# 2  Customer trip for Gary Hanks
# 3                   Caithness +
# 4        TECO EnergySource Inc.
#
#                                           email_body
# 0  note let know per conversation tanya review br...
# 1  peter ca recall sent override letter essential...
# 2  esther gary asked send info business trip invi...
# 3  thursday october 25 2001 pm central time u can...
# 4  tana eta amendment letter ready teco see could...

# %%
import matplotlib.pyplot as plt

def plot_data(data):
    lengths = [len(text.split()) for text in data['email_body']]
    plt.hist(lengths, bins=30)
    plt.xlabel('Length of email bodies')
    plt.ylabel('Frequency')
    plt.show()

plot_data(train_data)
plot_data(dev_data)
plot_data(test_data)

# %%
class EmailSubjectDataset(Dataset):
    def __init__(self, emails, subjects, tokenizer, max_length):
        self.emails = emails
        self.subjects = subjects
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.emails)

    def __getitem__(self, idx):
        email_text = self.emails[idx]
        subject_text = self.subjects[idx]

        # Tokenize inputs and outputs
        inputs = self.tokenizer.encode_plus(email_text, max_length=self.max_length, padding='max_length', return_tensors='pt', truncation=True)
        outputs = self.tokenizer.encode_plus(subject_text, max_length=self.max_length, padding='max_length', return_tensors='pt', truncation=True)

        return {
            'input_ids': inputs['input_ids'].flatten(),
            'attention_mask': inputs['attention_mask'].flatten(),
            'labels': outputs['input_ids'].flatten()
        }

# %%
from transformers import Trainer, TrainingArguments, T5Tokenizer, T5ForConditionalGeneration
import torch
from torch.utils.data import Dataset

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
dataset = EmailSubjectDataset(train_emails, tain_subjects, tokenizer, max_length=512)

# %%
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# %%
training_args = TrainingArguments(
    output_dir='./results',
    overwrite_output_dir=True,
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    logging_dir='./logs',
    logging_steps=500,
    eval_strategy="epoch",
)

# Initialize model
model = T5ForConditionalGeneration.from_pretrained('t5-base')

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer,
)

# Fine-tuning the model
trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
#     <div>
#
#       <progress value='2460' max='8661' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2460/8661 48:48 < 2:03:08, 0.84 it/s, Epoch 0.85/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='8661' max='8661' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8661/8661 3:05:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.022600</td>
#       <td>0.018911</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.018700</td>
#       <td>0.017477</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.016100</td>
#       <td>0.017105</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=8661, training_loss=0.020649030513871337, metrics={'train_runtime': 11119.8128, 'train_samples_per_second': 3.116, 'train_steps_per_second': 0.779, 'total_flos': 2.109673716056064e+16, 'train_loss': 0.020649030513871337, 'epoch': 3.0})

# %%
# Function to generate subject lines from email text
def get_first_four_words_split(text):
    words = text.split()
    return ' '.join(words[:4])

# %%
def generate_subject(model, tokenizer, email_text, max_length=512):
    # Move model to correct device
    device = next(model.parameters()).device

    email_text = preprocess_text(email_text)

    input_ids = tokenizer.encode(email_text, return_tensors='pt').to(device)  # Move input_ids to device

    # Generate subject line
    with torch.no_grad():
        output = model.generate(input_ids, max_length=max_length, num_beams=5, early_stopping=True)

    generated_subject = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_subject

# %%
# Example usage of subject line generation
example_email = "The following reports have been waiting for your approval for more than 4 days.Please review.Owner: James W Reitmeyer Report Name: JReitmeyer 10/24/01 Days In Mgr.Queue: 5"
generated_subject = generate_subject(model, tokenizer, example_email)
print("Generated Subject:", get_first_four_words_split(generated_subject))
# Out:
# Generated Subject: <pad> J.W. Reitmeyer Reports

# %%
example_email = "All,  The below Analyst & Associate recruiting dates require ENA participation at Manager level at above.In order to resource each of your departments it is important to have ENA's involvement and participation in the interviews and debrief sessions on Fantastic Friday and Super Saturday events.These de-brief sessions will allow you the opportunity to select candidates you wish to join your groups.The target  is to assign potential candidates to business units and departments from the outset.As ENA has the highest percentage of A&A rotating in its business unit, the participation of ENA at interview should reflect this.Therefore, please encourage your direct reports and managers to participate in the below events in order to secure candidates for your business area.Associate Recruiting:		Saturday November 3						Total - 70 Candidates for Interview Analyst Recruiting:		Friday, November 16						Total - 70 Candidates for Interivew Associate Recruiting:		Saturday, December 1						Total - 70 Candidates for Interview  The above spreadsheet represents ENA's particpation today which I believe highlights the need for much additional support in these efforts.Please confirm by return participation of your respective groups.Regards,"
generated_subject = generate_subject(model, tokenizer, example_email)
print("Generated Subject:", get_first_four_words_split(generated_subject))
# Out:
# Generated Subject: <pad> ENA/Analyst/Associate Recruiting

# %%
example_email = "Late on October 25th, we received information about a nonspecific threat to the Enron Center.We communicated with law enforcement officials who found the threat unsubstantiated and without merit.Nonetheless we take all threats seriously and have increased the security presence at the Enron Center still further.Once again, if you observe suspicious behavior, please call security at 3-6200."
generated_subject = generate_subject(model, tokenizer, example_email)
print("Generated Subject:", get_first_four_words_split(generated_subject))
# Out:
# Generated Subject: <pad> Enron Center

# %%
example_email = "Thanks in advance for agreeing to speak at the Global Operations Controller  Forum.There will be approximately 30 Enron business controllers present at  the meeting.All have responsibility for mid and back office operations for  the following Enron entities:  Enron North America, Enron Europe, Enron South  America, Enron Global Markets, Enron Industrial Markets, Enron Broadband  Services and Enron Energy Services.Attendees will be here from Houston,  Calgary, Tokyo, Sydney, London and New York (metals business).Attached for your reference is the agenda.There may be some slight changes  before the forum begins, but this will give you a good idea of the topics to  be covered and the other speakers who will address the group.You are scheduled to address the group as follows:"
generated_subject = generate_subject(model, tokenizer, example_email)
print("Generated Subject:", get_first_four_words_split(generated_subject))
# Out:
# Generated Subject: <pad> Topic Covered Speaker

# %%
example_email = "To confirm:  Mark Thomas Mike Presley  both previously on the list for Netco's Market Risk/Research Group have resigned.I'm combing the Estate for replacements.DP"
generated_subject = generate_subject(model, tokenizer, example_email)
print("Generated Subject:", get_first_four_words_split(generated_subject))
# Out:
# Generated Subject: <pad> Netco Market Group

# %%
example_email = "Michelle;  This is the presentation which was provided to the HR VP's.The HR VPs were tasked with going off to met their BU OTCs and devise plans around the three components.We are currently collating those plans into one document.We'll send that along to you when completed.Pls call if you have any questions."
generated_subject = generate_subject(model, tokenizer, example_email)
print("Generated Subject:", get_first_four_words_split(generated_subject))
# Out:
# Generated Subject: <pad> Ms. McKinnon

# %%
# Evaluate the model
evaluation_results = trainer.evaluate()
print(f"Evaluation results: {evaluation_results}")
# Out:
#     <div>
#
#       <progress value='722' max='722' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [722/722 04:37]
#     </div>
# Evaluation results: {'eval_loss': 0.017105471342802048, 'eval_runtime': 277.5043, 'eval_samples_per_second': 10.407, 'eval_steps_per_second': 2.602, 'epoch': 3.0}

# %%
# !pip install rouge_score

# %%
from rouge_score import rouge_scorer, scoring

# %%
import re

# Sample email body
email_body = """
All: Attached you will find a list that reflects your seat assignments for Business Continuity Planning (BCP).
These seats are located on the 30th and 31st Floors of Enron Center North (ECN).
As previously communicated, you will report to these designated seats in the event of an outage in ECS.
The exception to this is as follows: If your seat assignment is located on the 31st Floor, you will report to your original location that you occupied prior to your move into ECS.
This will hold true until the Monday after Thanksgiving, as we will have the 31st floor seats set up at that time.
Testing: Once you have moved to ECS, if you would like to test your BCP location, you will be able to test your seat for functionality every Thursday from 3-6pm.
Testing is not required, but is highly recommended.
If anyone has any questions or concerns about these procedures, please feel free to contact me at any time.
Regards,

@subject
BCP Seat Assignments

@ann0
your seat assignments for business continuity planning (bcp).

@ann1
bcp seat assignments

@ann2
here are your seat assignments for the business continuity planning event
"""

# %%
# Define a function to extract annotations
def extract_annotations(email_body):
    annotations = {}
    final_annotations = []
    current_annotation = None

    # Split the email body by lines
    lines = email_body.strip().split('\n')

    # Iterate through each line
    for line in lines:
        line = line.strip()

        # Check if line starts with @ann
        if line.startswith('@ann'):
            current_annotation = line
            annotations[current_annotation] = []
        elif current_annotation:
            # Append line to current annotation's text
            annotations[current_annotation].append(line)

    # Join lines of each annotation and return as dictionary values
    for key in annotations:
        annotations[key] = ' '.join(annotations[key])

    for key, value in annotations.items():
        final_annotations.append(value)

    return final_annotations

# %%
import os
from rouge import Rouge

# %%
def calculate_rouge_scores(hypotheses, references):
    rouge = Rouge()
    scores = rouge.get_scores(hypotheses, references, avg=True)
    return scores

# %%
data_dir = '/content/AESLC/enron_subject_line/test'

# %%
def extract_text_subject(email_body):
    # Check if @ann0 is present
    pattern_with_ann0 = r'@subject\n(.+?)\n@ann0'
    pattern_without_ann0 = r'@subject\n(.+)'
    if re.search('@ann0', email_body):
        match = re.search(pattern_with_ann0, email_body, re.DOTALL)
        if match:
            return match.group(1).strip()
    else:
        match = re.search(pattern_without_ann0, email_body, re.DOTALL)
        if match:
            return match.group(1).strip()

    return None  # Return None if no match found

# %%
# Function to load data from a directory
def load_data_from_directory(data_dir):
    hypotheses = []
    references = []

    # Iterate over files in the directory
    count =1
    for filename in os.listdir(data_dir):
        count = count+1
        if count > 600:
            break
        print(filename)
        with open(os.path.join(data_dir, filename), 'r', encoding='utf-8', errors='ignore') as file:
            email_text = file.read()

            annotations =  extract_annotations(email_text)
            # Extract subject from email body using regex

            subject = extract_text_subject(email_text)
            annotations.append(subject)

            pattern = r'(.+)(?=@subject)'

            # Use re.search to find the matching text
            match = re.search(pattern, email_text, re.DOTALL)
            text_before_subject = ""
            if match:
                text_before_subject = match.group(1).strip()
                # print("Text before @subject:")
                # print(text_before_subject)
            else:
                print("No match found.")
            text_before_subject = text_before_subject[:512]
            hypotheses.append(get_first_four_words_split(generate_subject(model,tokenizer,text_before_subject)))
            references.append(annotations)
            #print(annotations)




    return hypotheses, references

# %%
# Generate hypotheses and references
hypotheses, references = load_data_from_directory(data_dir)
hypotheses = [hypothesis.strip() for hypothesis in hypotheses]
references = [' '.join(reference).strip() for reference in references]
# Out:
# nemec-g_inbox_868.subject
# sanders-r_inbox_9.subject
# stclair-c_sent_32.subject
# martin-t_inbox_141.subject
# nemec-g_sent_2310.subject
# lay-k_inbox_126.subject
# may-l_inbox_280.subject
# lay-k_inbox_227.subject
# beck-s_sent_243.subject
# holst-k_inbox_18.subject
# campbell-l_inbox_419.subject
# jones-t_sent_2407.subject
# richey-c_inbox_18.subject
# rodrique-r_sent_576.subject
# baughman-d_inbox_120.subject
# mcconnell-m_sent_424.subject
# keavey-p_inbox_212.subject
# cash-m_inbox_51.subject
# lay-k_inbox_719.subject
# symes-k_sent_403.subject
# lay-k_inbox_340.subject
# dasovich-j_sent_567.subject
# lay-k_inbox_102.subject
# jones-t_sent_5941.subject
# tycholiz-b_inbox_280.subject
# farmer-d_inbox_54.subject
# shackleton-s_sent_391.subject
# dorland-c_inbox_4.subject
# townsend-j_inbox_280.subject
# saibi-e_inbox_591.subject
# haedicke-m_sent_48.subject
# platter-p_inbox_330.subject
# germany-c_sent_1145.subject
# sturm-f_sent_72.subject
# sturm-f_inbox_104.subject
# mann-k_sent_1681.subject
# jones-t_sent_669.subject
# nemec-g_sent_2571.subject
# holst-k_inbox_123.subject
# hodge-j_inbox_479.subject
# cash-m_inbox_158.subject
# pimenov-v_inbox_156.subject
# nemec-g_sent_2469.subject
# ybarbo-p_inbox_119.subject
# saibi-e_inbox_1004.subject
# shackleton-s_sent_5799.subject
# perlingiere-d_sent_319.subject
# bass-e_sent_1240.subject
# beck-s_inbox_241.subject
# nemec-g_sent_186.subject
# giron-d_sent_595.subject
# taylor-m_inbox_79.subject
# geaccone-t_inbox_232.subject
# may-l_inbox_173.subject
# stclair-c_sent_439.subject
# neal-s_inbox_87.subject
# townsend-j_inbox_149.subject
# ward-k_inbox_147.subject
# swerzbin-m_inbox_59.subject
# smith-m_inbox_240.subject
# wolfe-j_inbox_223.subject
# shackleton-s_sent_1497.subject
# blair-l_inbox_198.subject
# farmer-d_sent_188.subject
# swerzbin-m_inbox_31.subject
# mann-k_sent_3351.subject
# dasovich-j_inbox_215.subject
# mcconnell-m_sent_327.subject
# taylor-m_sent_555.subject
# sanders-r_inbox_48.subject
# salisbury-h_inbox_769.subject
# haedicke-m_inbox_540.subject
# rogers-b_sent_152.subject
# hodge-j_inbox_418.subject
# scott-s_inbox_325.subject
# martin-t_inbox_67.subject
# kean-s_sent_80.subject
# bass-e_sent_341.subject
# whalley-g_inbox_52.subject
# buy-r_inbox_440.subject
# buy-r_inbox_833.subject
# jones-t_sent_2282.subject
# lay-k_inbox_542.subject
# swerzbin-m_inbox_241.subject
# fossum-d_sent_358.subject
# giron-d_inbox_14.subject
# pimenov-v_inbox_109.subject
# bass-e_sent_329.subject
# germany-c_sent_1027.subject
# fischer-m_sent_22.subject
# dasovich-j_sent_4553.subject
# bass-e_sent_933.subject
# jones-t_sent_1662.subject
# whalley-g_inbox_180.subject
# lay-k_inbox_9.subject
# dasovich-j_sent_576.subject
# love-p_sent_862.subject
# swerzbin-m_inbox_249.subject
# stclair-c_sent_190.subject
# carson-m_inbox_86.subject
# buy-r_inbox_230.subject
# baughman-d_inbox_222.subject
# sturm-f_sent_8.subject
# white-s_inbox_192.subject
# dasovich-j_sent_2826.subject
# parks-j_inbox_550.subject
# germany-c_sent_367.subject
# lewis-a_inbox_11.subject
# lucci-p_inbox_174.subject
# storey-g_inbox_20.subject
# jones-t_inbox_977.subject
# mann-k_sent_4377.subject
# beck-s_sent_804.subject
# germany-c_sent_1044.subject
# shackleton-s_sent_308.subject
# nemec-g_inbox_329.subject
# shackleton-s_sent_1883.subject
# quigley-d_inbox_8.subject
# lokey-t_inbox_235.subject
# mims-thurston-p_inbox_356.subject
# beck-s_inbox_410.subject
# lokey-t_inbox_125.subject
# lokey-t_inbox_689.subject
# shackleton-s_inbox_672.subject
# hernandez-j_inbox_199.subject
# hernandez-j_inbox_340.subject
# shackleton-s_inbox_463.subject
# nemec-g_sent_6.subject
# keavey-p_inbox_432.subject
# ybarbo-p_inbox_87.subject
# love-p_inbox_68.subject
# mann-k_sent_70.subject
# mclaughlin-e_inbox_213.subject
# nemec-g_inbox_730.subject
# taylor-m_sent_939.subject
# dean-c_inbox_28.subject
# beck-s_sent_133.subject
# salisbury-h_inbox_892.subject
# beck-s_sent_729.subject
# saibi-e_inbox_736.subject
# buy-r_inbox_522.subject
# tycholiz-b_inbox_446.subject
# nemec-g_inbox_395.subject
# dasovich-j_inbox_123.subject
# buy-r_inbox_650.subject
# stclair-c_sent_735.subject
# shackleton-s_sent_1713.subject
# stclair-c_sent_764.subject
# haedicke-m_inbox_299.subject
# bass-e_sent_608.subject
# nemec-g_inbox_924.subject
# mcconnell-m_inbox_41.subject
# storey-g_inbox_17.subject
# hernandez-j_inbox_188.subject
# salisbury-h_inbox_212.subject
# beck-s_sent_222.subject
# nemec-g_sent_2279.subject
# watson-k_inbox_116.subject
# whalley-g_inbox_486.subject
# buy-r_inbox_587.subject
# wolfe-j_inbox_208.subject
# delainey-d_sent_661.subject
# nemec-g_sent_45.subject
# perlingiere-d_sent_1987.subject
# dasovich-j_inbox_1792.subject
# arora-h_inbox_3.subject
# nemec-g_sent_619.subject
# skilling-j_inbox_1287.subject
# harris-s_inbox_23.subject
# salisbury-h_inbox_562.subject
# mcconnell-m_sent_8.subject
# symes-k_sent_1085.subject
# benson-r_inbox_47.subject
# holst-k_inbox_43.subject
# pimenov-v_inbox_148.subject
# saibi-e_inbox_582.subject
# motley-m_inbox_73.subject
# jones-t_inbox_1044.subject
# jones-t_sent_2523.subject
# perlingiere-d_sent_2704.subject
# whitt-m_inbox_390.subject
# stclair-c_sent_201.subject
# dasovich-j_sent_50.subject
# salisbury-h_inbox_1044.subject
# lay-k_inbox_1841.subject
# skilling-j_inbox_1458.subject
# mims-thurston-p_inbox_349.subject
# campbell-l_inbox_177.subject
# buy-r_inbox_983.subject
# hodge-j_inbox_393.subject
# cash-m_sent_237.subject
# buy-r_inbox_168.subject
# hodge-j_inbox_458.subject
# dean-c_inbox_506.subject
# taylor-m_sent_736.subject
# reitmeyer-j_inbox_384.subject
# mckay-b_inbox_43.subject
# beck-s_sent_643.subject
# dasovich-j_sent_12208.subject
# nemec-g_inbox_1438.subject
# keavey-p_sent_41.subject
# jones-t_sent_5879.subject
# sager-e_inbox_862.subject
# jones-t_inbox_6.subject
# perlingiere-d_sent_2349.subject
# mclaughlin-e_sent_46.subject
# mann-k_sent_672.subject
# whalley-l_sent_122.subject
# saibi-e_inbox_763.subject
# kaminski-v_inbox_405.subject
# lay-k_inbox_551.subject
# rogers-b_sent_174.subject
# shackleton-s_sent_1363.subject
# mann-k_sent_1092.subject
# skilling-j_inbox_92.subject
# lay-k_inbox_857.subject
# dickson-s_sent_16.subject
# skilling-j_inbox_2458.subject
# ermis-f_inbox_527.subject
# shackleton-s_sent_299.subject
# mann-k_sent_3747.subject
# buy-r_inbox_467.subject
# hodge-j_inbox_24.subject
# hodge-j_inbox_506.subject
# shackleton-s_sent_6005.subject
# tycholiz-b_inbox_334.subject
# reitmeyer-j_inbox_91.subject
# lokey-t_inbox_938.subject
# skilling-j_inbox_1192.subject
# delainey-d_sent_261.subject
# love-p_sent_611.subject
# ybarbo-p_inbox_159.subject
# haedicke-m_inbox_13.subject
# martin-t_inbox_57.subject
# haedicke-m_sent_679.subject
# cash-m_inbox_288.subject
# smith-m_inbox_4.subject
# mclaughlin-e_inbox_4.subject
# whitt-m_inbox_247.subject
# carson-m_inbox_26.subject
# jones-t_sent_5681.subject
# keavey-p_inbox_252.subject
# scott-s_sent_47.subject
# germany-c_inbox_386.subject
# shackleton-s_sent_1387.subject
# sanchez-m_inbox_32.subject
# salisbury-h_inbox_763.subject
# zufferli-j_inbox_1.subject
# scott-s_inbox_276.subject
# jones-t_sent_5703.subject
# shively-h_inbox_111.subject
# kaminski-v_sent_1430.subject
# salisbury-h_inbox_793.subject
# may-l_inbox_346.subject
# sager-e_inbox_487.subject
# hyvl-d_sent_453.subject
# williams-j_inbox_10.subject
# campbell-l_inbox_470.subject
# saibi-e_inbox_38.subject
# bass-e_inbox_147.subject
# beck-s_sent_723.subject
# lokey-t_inbox_162.subject
# kean-s_sent_32.subject
# mann-k_sent_2582.subject
# campbell-l_inbox_172.subject
# allen-p_inbox_84.subject
# jones-t_inbox_721.subject
# germany-c_inbox_24.subject
# beck-s_sent_1020.subject
# solberg-g_inbox_58.subject
# taylor-m_sent_1373.subject
# grigsby-m_sent_227.subject
# shackleton-s_inbox_3.subject
# rogers-b_sent_853.subject
# perlingiere-d_sent_2054.subject
# germany-c_sent_1955.subject
# germany-c_inbox_222.subject
# mann-k_sent_989.subject
# lavorato-j_sent_328.subject
# whalley-g_inbox_79.subject
# shackleton-s_sent_2524.subject
# williams-j_inbox_127.subject
# parks-j_inbox_511.subject
# tholt-j_inbox_140.subject
# salisbury-h_inbox_1029.subject
# shackleton-s_sent_2383.subject
# geaccone-t_inbox_277.subject
# jones-t_sent_5886.subject
# donoho-l_inbox_191.subject
# may-l_inbox_369.subject
# lokey-t_inbox_223.subject
# beck-s_inbox_348.subject
# may-l_inbox_915.subject
# martin-t_inbox_55.subject
# bass-e_inbox_87.subject
# salisbury-h_inbox_535.subject
# shackleton-s_sent_5642.subject
# buy-r_inbox_315.subject
# giron-d_inbox_119.subject
# nemec-g_sent_769.subject
# delainey-d_sent_671.subject
# salisbury-h_inbox_1020.subject
# buy-r_inbox_97.subject
# saibi-e_inbox_456.subject
# gilbertsmith-d_inbox_36.subject
# dasovich-j_inbox_1021.subject
# mann-k_sent_2563.subject
# tycholiz-b_inbox_299.subject
# mann-k_sent_3929.subject
# dasovich-j_inbox_813.subject
# hayslett-r_inbox_216.subject
# whitt-m_inbox_854.subject
# mann-k_sent_626.subject
# scott-s_sent_741.subject
# baughman-d_inbox_82.subject
# beck-s_sent_836.subject
# kean-s_sent_68.subject
# haedicke-m_inbox_116.subject
# hayslett-r_inbox_167.subject
# mann-k_sent_365.subject
# donohoe-t_inbox_33.subject
# smith-m_inbox_276.subject
# beck-s_sent_593.subject
# salisbury-h_inbox_712.subject
# dasovich-j_sent_1154.subject
# benson-r_inbox_156.subject
# benson-r_inbox_248.subject
# shackleton-s_sent_1561.subject
# dasovich-j_inbox_1311.subject
# nemec-g_sent_444.subject
# donoho-l_inbox_84.subject
# shackleton-s_sent_6266.subject
# mann-k_sent_1290.subject
# hodge-j_inbox_881.subject
# fossum-d_sent_1022.subject
# dean-c_inbox_169.subject
# rodrique-r_sent_648.subject
# jones-t_sent_6451.subject
# kaminski-v_sent_1228.subject
# nemec-g_inbox_767.subject
# donohoe-t_inbox_174.subject
# may-l_inbox_1059.subject
# pereira-s_sent_25.subject
# lokey-t_inbox_615.subject
# cuilla-m_sent_9.subject
# causholli-m_inbox_142.subject
# wolfe-j_inbox_69.subject
# dasovich-j_sent_4081.subject
# baughman-d_inbox_194.subject
# geaccone-t_inbox_183.subject
# jones-t_sent_2437.subject
# campbell-l_inbox_563.subject
# may-l_inbox_306.subject
# germany-c_sent_220.subject
# blair-l_inbox_15.subject
# nemec-g_inbox_1759.subject
# shackleton-s_sent_5454.subject
# bass-e_sent_794.subject
# lokey-t_inbox_50.subject
# jones-t_inbox_561.subject
# hayslett-r_inbox_13.subject
# delainey-d_sent_660.subject
# jones-t_sent_6434.subject
# townsend-j_inbox_113.subject
# kaminski-v_sent_1818.subject
# cash-m_inbox_68.subject
# saibi-e_inbox_39.subject
# mann-k_sent_519.subject
# campbell-l_inbox_530.subject
# nemec-g_sent_755.subject
# lewis-a_inbox_27.subject
# ruscitti-k_inbox_28.subject
# dasovich-j_inbox_1461.subject
# buy-r_inbox_1100.subject
# nemec-g_inbox_439.subject
# salisbury-h_inbox_1113.subject
# beck-s_sent_189.subject
# haedicke-m_inbox_543.subject
# kean-s_inbox_21.subject
# donoho-l_inbox_141.subject
# kaminski-v_sent_4501.subject
# scott-s_sent_836.subject
# salisbury-h_inbox_844.subject
# dasovich-j_inbox_1605.subject
# arnold-j_inbox_27.subject
# germany-c_sent_1691.subject
# shackleton-s_inbox_237.subject
# zipper-a_inbox_62.subject
# whitt-m_inbox_54.subject
# lay-k_inbox_815.subject
# ermis-f_inbox_557.subject
# cash-m_inbox_98.subject
# haedicke-m_sent_868.subject
# beck-s_sent_451.subject
# bass-e_sent_1292.subject
# ermis-f_inbox_512.subject
# martin-t_inbox_453.subject
# fossum-d_sent_244.subject
# martin-t_inbox_128.subject
# rapp-b_inbox_22.subject
# perlingiere-d_inbox_117.subject
# maggi-m_inbox_22.subject
# parks-j_inbox_89.subject
# hodge-j_inbox_675.subject
# sanchez-m_inbox_24.subject
# beck-s_sent_889.subject
# sager-e_sent_825.subject
# nemec-g_sent_384.subject
# mann-k_sent_2136.subject
# ruscitti-k_inbox_273.subject
# shackleton-s_sent_5546.subject
# reitmeyer-j_inbox_424.subject
# whalley-g_inbox_259.subject
# hernandez-j_sent_275.subject
# arora-h_inbox_17.subject
# taylor-m_sent_1007.subject
# rapp-b_inbox_388.subject
# wolfe-j_inbox_313.subject
# shackleton-s_sent_2410.subject
# saibi-e_inbox_522.subject
# buy-r_inbox_154.subject
# salisbury-h_inbox_1043.subject
# farmer-d_inbox_13.subject
# beck-s_inbox_488.subject
# zipper-a_inbox_226.subject
# sager-e_sent_244.subject
# derrick-j_inbox_165.subject
# causholli-m_inbox_132.subject
# keavey-p_inbox_400.subject
# salisbury-h_inbox_431.subject
# tholt-j_sent_137.subject
# germany-c_inbox_108.subject
# fossum-d_sent_1252.subject
# ybarbo-p_inbox_274.subject
# kean-s_sent_1639.subject
# dasovich-j_sent_4011.subject
# shackleton-s_sent_1575.subject
# salisbury-h_inbox_276.subject
# dasovich-j_sent_4289.subject
# mann-k_sent_4164.subject
# saibi-e_inbox_706.subject
# lokay-m_sent_52.subject
# hodge-j_inbox_878.subject
# stclair-c_sent_116.subject
# lay-k_inbox_1811.subject
# skilling-j_inbox_216.subject
# mann-k_sent_541.subject
# jones-t_sent_5595.subject
# mcconnell-m_sent_326.subject
# gilbertsmith-d_inbox_44.subject
# whalley-g_inbox_32.subject
# kaminski-v_inbox_420.subject
# buy-r_inbox_433.subject
# buy-r_inbox_735.subject
# haedicke-m_sent_41.subject
# lokey-t_inbox_64.subject
# symes-k_sent_1084.subject
# may-l_inbox_324.subject
# lenhart-m_inbox_7.subject
# mims-thurston-p_inbox_445.subject
# delainey-d_sent_543.subject
# salisbury-h_inbox_825.subject
# beck-s_sent_470.subject
# dean-c_inbox_53.subject
# sager-e_sent_14.subject
# jones-t_sent_2118.subject
# sturm-f_inbox_52.subject
# tycholiz-b_inbox_224.subject
# jones-t_inbox_126.subject
# campbell-l_inbox_851.subject
# shackleton-s_inbox_1086.subject
# shackleton-s_sent_660.subject
# donohoe-t_inbox_82.subject
# tholt-j_inbox_62.subject
# nemec-g_sent_2074.subject
# badeer-r_inbox_2.subject
# giron-d_sent_363.subject
# haedicke-m_sent_388.subject
# lay-k_inbox_935.subject
# townsend-j_inbox_55.subject
# williams-j_inbox_55.subject
# dasovich-j_inbox_304.subject
# lokey-t_inbox_816.subject
# williams-w3_inbox_29.subject
# shackleton-s_sent_5424.subject
# haedicke-m_inbox_271.subject
# campbell-l_sent_145.subject
# dean-c_inbox_617.subject
# shackleton-s_sent_291.subject
# stclair-c_sent_608.subject
# may-l_inbox_141.subject
# shackleton-s_inbox_22.subject
# dasovich-j_sent_801.subject
# shackleton-s_sent_5498.subject
# dasovich-j_sent_2995.subject
# schoolcraft-d_inbox_62.subject
# shackleton-s_sent_1365.subject
# stclair-c_sent_18.subject
# townsend-j_inbox_101.subject
# rogers-b_inbox_285.subject
# delainey-d_sent_534.subject
# parks-j_inbox_133.subject
# hernandez-j_inbox_311.subject
# germany-c_sent_2132.subject
# germany-c_inbox_250.subject
# keavey-p_inbox_188.subject
# hernandez-j_inbox_67.subject
# buy-r_inbox_23.subject
# reitmeyer-j_inbox_157.subject
# causholli-m_inbox_32.subject
# jones-t_sent_2608.subject
# donohoe-t_inbox_363.subject
# allen-p_inbox_6.subject
# skilling-j_inbox_132.subject
# thomas-p_inbox_277.subject
# dean-c_inbox_12.subject
# lay-k_inbox_31.subject
# crandell-s_inbox_18.subject
# nemec-g_sent_2006.subject
# skilling-j_inbox_185.subject
# germany-c_sent_1175.subject
# nemec-g_inbox_437.subject
# donohoe-t_inbox_114.subject
# hodge-j_inbox_86.subject
# salisbury-h_inbox_134.subject
# mann-k_sent_4150.subject
# lokey-t_inbox_918.subject
# ybarbo-p_inbox_185.subject
# stclair-c_sent_351.subject
# skilling-j_inbox_1388.subject
# lay-k_inbox_860.subject
# whalley-l_sent_242.subject
# farmer-d_sent_672.subject
# perlingiere-d_sent_12.subject
# beck-s_sent_177.subject
# mann-k_sent_3422.subject
# shackleton-s_sent_463.subject
# smith-m_inbox_182.subject
# buy-r_inbox_1188.subject
# giron-d_inbox_149.subject
# shackleton-s_sent_5251.subject
# kitchen-l_inbox_14.subject
# shackleton-s_sent_1367.subject
# saibi-e_inbox_754.subject
# shackleton-s_sent_1977.subject
# hayslett-r_inbox_3.subject
# keiser-k_inbox_200.subject
# skilling-j_inbox_1561.subject
# salisbury-h_inbox_1031.subject
# skilling-j_inbox_1079.subject
# martin-t_inbox_233.subject
# dasovich-j_inbox_694.subject
# perlingiere-d_sent_1819.subject
# nemec-g_inbox_434.subject
# lay-k_inbox_1049.subject
# stclair-c_sent_364.subject
# skilling-j_inbox_380.subject
# keiser-k_inbox_98.subject
# kean-s_sent_146.subject
# campbell-l_sent_17.subject
# thomas-p_inbox_390.subject
# buy-r_inbox_267.subject
# haedicke-m_inbox_656.subject
# mann-k_sent_1263.subject
# nemec-g_inbox_418.subject
# kaminski-v_sent_271.subject
# lavorato-j_inbox_255.subject
# nemec-g_inbox_965.subject
# neal-s_inbox_159.subject
# germany-c_inbox_103.subject
# shackleton-s_inbox_259.subject
# mann-k_sent_600.subject
# skilling-j_inbox_167.subject
# hayslett-r_inbox_174.subject
# perlingiere-d_sent_267.subject
# campbell-l_inbox_121.subject
# lay-k_inbox_1759.subject
# lavorato-j_sent_194.subject
# salisbury-h_inbox_1099.subject
# skilling-j_inbox_1550.subject
# germany-c_sent_871.subject
# scott-s_sent_842.subject
# dean-c_inbox_705.subject
# shackleton-s_inbox_687.subject
# jones-t_inbox_594.subject
# arnold-j_inbox_141.subject
# bass-e_inbox_254.subject
# campbell-l_inbox_853.subject
# scott-s_sent_420.subject
# mcconnell-m_sent_686.subject
# jones-t_sent_2314.subject
# brawner-s_inbox_35.subject
# nemec-g_sent_765.subject
# shackleton-s_sent_6234.subject
# williams-j_inbox_156.subject
# fischer-m_sent_3.subject
# townsend-j_inbox_185.subject
# blair-l_inbox_77.subject
# shankman-j_inbox_109.subject

# %%
hypotheses

# %%
from rouge import Rouge

def calculate_rouge_scores(hypotheses, references):
    if not hypotheses:
        raise ValueError("Hypotheses list is empty.")
    if not references:
        raise ValueError("References list is empty.")

    rouge = Rouge()
    scores = rouge.get_scores(hypotheses, references, avg=True)
    return scores

print("Hypotheses:", hypotheses)
print("References:", references)

try:
    rouge_scores = calculate_rouge_scores(hypotheses, references)

    # Print ROUGE scores
    print("ROUGE Scores:")
    print("ROUGE-1 (Recall):", rouge_scores['rouge-1'])
    print("ROUGE-2 (Recall):", rouge_scores['rouge-2'])
    print("ROUGE-L (Recall):", rouge_scores['rouge-l'])
except ValueError as e:
    print(e)
# Out:
# Hypotheses: ['<pad> GISB Gas', '<pad> a.k.a.', '<pad> Thanks Carol', '<pad> Email Reminder', '<pad> guaranty', '<pad> EDT/Cowen/Ross/Ross/Ross/Ross/Ross', "<pad> I'm a Trader!", '<pad> Trade Press Media', '<pad> Looking forward to', '<pad> How are you?', '<pad> October 5 -', '<pad> Dovie Keprta-Emarket Services', '<pad> e-mail cheat sheet', '<pad> Book Included Portfolio', '<pad> Enron Center North/Enron', '<pad> eGM', '<pad> EIM - Fundamental', '<pad> PBS Call for', "<pad> What's Up", '<pad> How are you?', '<pad> EES/Enron', '<pad> Best of both', '<pad> I met Senator', '<pad> European Physical and', "<pad> Xcel's Short Presentation", '<pad> Thank You', '<pad> sara', '<pad> PRIOR TO MARKETING', '<pad> Enron Center South', '<pad> Outage Database', '<pad> Weather/Energy', '<pad> U.S. Market Uncertainty', '<pad> Sitara/Sitara', '<pad> EOL', '<pad> NRC Request for', '<pad> tres palacios matagorda', '<pad> EOL/Enron Counterparty Lists', '<pad> aep', '<pad> Metro Passes', '<pad> Memo/Favorite Forms', '<pad> Thank you', '<pad> 6 Boxes &', '<pad> Thank you', '<pad> How are you?', "<pad> Enron Kids' Holiday", '<pad> Thank you', '<pad> Corporate Structure and', '<pad> hpl', '<pad> Thank You!', '<pad> We look forward', '<pad> Postid-Net Position Officialized', '<pad> November Elections', '<pad> Questionnaire - General', '<pad> Carr Futures Officer,', '<pad> El Paso collateral', '<pad> ENA Trading Tracks', '<pad> eW Brown Bag', '<pad> Thanks for your', '<pad> Please allow at', '<pad> Brown Bag', '<pad> Enron Email Retention', '<pad> Utilicorp and UtiliCorps', '<pad> LYNN', '<pad> TUFCO - Q&A', '<pad> CALPINE - EPS', '<pad> GE/Purplepark version', '<pad> SVMG Annual Planning', '<pad> Thank you!', "<pad> I'm a TA", "<pad> What's Up", '<pad> Funeral for Andy,', "<pad> What's Up", "<pad> Ben's Help", '<pad> Enron North America', '<pad> Enron, Inc. ("Enron"),', '<pad> 1099r', "<pad> I'd like to", '<pad> DAVE STEVEN', '<pad> Enron/Enron Employee Meeting', '<pad> RESPONSIBILITY FOOTBAR', '<pad> Draft Watch Report', '<pad> Deutsche Bank -', '<pad> Thank you for', "<pad> Summary of Senate's", '<pad> GL&E', '<pad> UBSWE Enviro', '<pad> EXPLORATION POINTS -', '<pad> 2302 Travis St', "<pad> I'm a seasonal", '<pad> The Pareto Faults', '<pad> Enron/Edison', '<pad> 9911 PMA and', '<pad> City of Huntsville', '<pad> Goughary Gasoline Distillate', '<pad> Office of Industrial', "<pad> What's Up?", '<pad> Please help!', '<pad> 4/24/01 load taken', '<pad> Taffy', '<pad> Natural Gas', '<pad> Thanks a lot!', '<pad> Your mailbox is', '<pad> Thank You!', "<pad> What's Up?", '<pad> Happy New Year!', '<pad> mccomb/shitty deer', '<pad> vng sure set', '<pad> e-mail cheat sheet', '<pad> lorraine', '<pad> FOIA/FBI', '<pad> Isda/Enron', '<pad> Kay', '<pad> @MaxDoorReviews', '<pad> psnc invoices', '<pad> Susan Bailey -', '<pad> Meeting Regards', '<pad> ENA/Midwest', '<pad> e-mail cheat sheet', '<pad> Enron JDRF-Walking with', '<pad> Thank You', '<pad> Weekly Summary of', '<pad> TW Marketing, Inc.', '<pad> TEB Rating Outline', '<pad> NEXT WEEK', '<pad> Thursday, November 01,', '<pad> Enron Management Committee', '<pad> FOLLOW-UP', '<pad> Insurance requirements', '<pad> Basics of E-Survey', '<pad> POSREP - HOEGH', "<pad> I'm not sure", '<pad> Consolidation Agreement', '<pad> Enron Savings Plan', '<pad> Questar Sonoran Open', "<pad> Isda's", '<pad> Enron, Inc. ("Enron"),', '<pad> Enron North America,', '<pad> EPMI/Mirant Cuts and', "<pad> What's Up?", '<pad> The Breakfast Club', '<pad> cindy hudler -', '<pad> Thank You', '<pad> Tractebel Energy Marketing', '<pad> M.A.', '<pad> Enron Broadband Notification', '<pad> Oneok Gas Marketing', "<pad> Mary's Counterparty List", '<pad> DBS language comments', '<pad> nepco', '<pad> Picking Draft Order', '<pad> You are a', '<pad> Your Ministry on', '<pad> Enron', "<pad> I'm seeing you!", '<pad> pdrive/terminal server issues', '<pad> Sally CA', '<pad> How are you?', '<pad> AFUDC', '<pad> Enron', '<pad> reorganized Executive Summary', '< ...
# References: ['gisb with tenn. gas status  implementing gisb with tenn gas final execution  re: gisb with tenn. gas Tennessee Gas Pipeling GISB', 'freeze destruction of electronic mail  bid/ask litigation request  please freeze destruction of e-mails Request for Freeze on E-Mail Destruction', 'call me for annex a  request for contact regarding the annex a mail out.  please call regarding annex a mail-out Annex A Letter', 'reminder on update of email domains effective 1/18  deadline: email domains will be no longer available  email domains to be decommissioned UPDATE: Supported Internet Email Addresses', 'attached: guaranty for approval  please approve guaranty  attached guaranty. Enron Corp. Guaranty', "compaq's analyst reports  important file, please read  read the following that tracks copmpaq's performance Financial Analysts' Reports for 6.05.01", 'joining a trading team  seeking junior trader position  farewell for now Good bye! from George Huan', 'referral of calls  callers using false identities  refer calls to public relations Solicitation Calls', 'just getting back to you.  got message - will be in chicago soon  thank you, i will see you soon. Welcome to Chicago and ENA', 'hi, hope all is well!  update on london details  hello from london London', "10/5 meeting agenda attached; deadline to add items is 3 p.m. tomorrow  here's the first draft of the icap working group meeting agenda on 10/5  nyiso_tech_exchange discussion list Draft ICAP WG AGENDA FOR OCt. 5", "david endicott's review needed for non-disclosure agreement  proposed non-disclosure agreement for review  comments please: nda draft + changes NDA-Sabre Corporation", 'instructions for documents  new data copying instructions  cheat sheet for data copy YOU HAVE 48 HOURS - Message from Louise Kitchen', 'pwr-gas-lt-mgmt-prc book  pwr-gas-lt-mgmt-prc book  pwr-gas-lt-mgmt-prc book PWR-GAS-LT-MGMT-PRC', 'important:  fire drill  information regarding the fire drill scheduled for the enron center campus required by the houston fire department.  fire drill scheduled for enron center campus on thursday december 20th Fire Drill Scheduled', 'your businesses remain in egm  your businesses remain in egm  businesses to remain in egm reorg.', 'enron industrial markets metal bulletin  business highlights re enron industrial markets metal bulletin  enron business highlights EnTouch Newsletter', 'bu otcs and devise plans  document plan formatting  hr vp presentation PRC Presentation', 'thoughts and encouragement from loyal employee  words of encouragement  encouragement and confidence from a new employee Vote of Confidence', 'jan. 16 deals.  questions about entries for 1/16  some pertinent questions re: your jan. 16 deals Los Angeles Department of Water and Power IS NOT LADWPPX', 'please advise of company situation, employees concerned  your a/a associates seek reassurance regarding recent news  requesting clarification about recent announcement Information', 'scheduled call time  bowen set time  appointment with bowen confirmation and other details Good News--Twice!', "time to transition to responsible energy  requesting your support calif energy policy  support for panel to evaluate california's energy policy Calif energy panle/ new energy policy for US", 'questioning about counterparties  clarfication re: counterparty trade  london approval of non us & canadian based products Amerada-Hess Corporation', 'consumer presentations for reference  attached short presentation regarding products  blend and extend product presentation Blend & Extend', 'presentation review  presentation review  upcoming meetings Ship Channel Hub Co', 'reschedule for 9 am (11 am sao paulo) fri sept 17  reschedule details  no response from assistant... rescheduled phone call', 'latest marketing list  latest copy of the marketing list  updated marketing list Latest Marketing List', 'technology information for enron center south  orientation to your environment and future technology  enron center south welco ...
# ROUGE Scores:
# ROUGE-1 (Recall): {'r': 0.03154395912506345, 'p': 0.1230383973288815, 'f': 0.049056511984150286}
# ROUGE-2 (Recall): {'r': 0.005602954653821968, 'p': 0.0333889816360601, 'f': 0.009468168063049351}
# ROUGE-L (Recall): {'r': 0.030224434359121283, 'p': 0.11775180856983863, 'f': 0.04697395998143783}
# Hypotheses: ['<pad> GISB Gas', '<pad> a.k.a.', '<pad> Thanks Carol', '<pad> Email Reminder', '<pad> guaranty', '<pad> EDT/Cowen/Ross/Ross/Ross/Ross/Ross', "<pad> I'm a Trader!", '<pad> Trade Press Media', '<pad> Looking forward to', '<pad> How are you?', '<pad> October 5 -', '<pad> Dovie Keprta-Emarket Services', '<pad> e-mail cheat sheet', '<pad> Book Included Portfolio', '<pad> Enron Center North/Enron', '<pad> eGM', '<pad> EIM - Fundamental', '<pad> PBS Call for', "<pad> What's Up", '<pad> How are you?', '<pad> EES/Enron', '<pad> Best of both', '<pad> I met Senator', '<pad> European Physical and', "<pad> Xcel's Short Presentation", '<pad> Thank You', '<pad> sara', '<pad> PRIOR TO MARKETING', '<pad> Enron Center South', '<pad> Outage Database', '<pad> Weather/Energy', '<pad> U.S. Market Uncertainty', '<pad> Sitara/Sitara', '<pad> EOL', '<pad> NRC Request for', '<pad> tres palacios matagorda', '<pad> EOL/Enron Counterparty Lists', '<pad> aep', '<pad> Metro Passes', '<pad> Memo/Favorite Forms', '<pad> Thank you', '<pad> 6 Boxes &', '<pad> Thank you', '<pad> How are you?', "<pad> Enron Kids' Holiday", '<pad> Thank you', '<pad> Corporate Structure and', '<pad> hpl', '<pad> Thank You!', '<pad> We look forward', '<pad> Postid-Net Position Officialized', '<pad> November Elections', '<pad> Questionnaire - General', '<pad> Carr Futures Officer,', '<pad> El Paso collateral', '<pad> ENA Trading Tracks', '<pad> eW Brown Bag', '<pad> Thanks for your', '<pad> Please allow at', '<pad> Brown Bag', '<pad> Enron Email Retention', '<pad> Utilicorp and UtiliCorps', '<pad> LYNN', '<pad> TUFCO - Q&A', '<pad> CALPINE - EPS', '<pad> GE/Purplepark version', '<pad> SVMG Annual Planning', '<pad> Thank you!', "<pad> I'm a TA", "<pad> What's Up", '<pad> Funeral for Andy,', "<pad> What's Up", "<pad> Ben's Help", '<pad> Enron North America', '<pad> Enron, Inc. ("Enron"),', '<pad> 1099r', "<pad> I'd like to", '<pad> DAVE STEVEN', '<pad> Enron/Enron Employee Meeting', '<pad> RESPONSIBILITY FOOTBAR', '<pad> Draft Watch Report', '<pad> Deutsche Bank -', '<pad> Thank you for', "<pad> Summary of Senate's", '<pad> GL&E', '<pad> UBSWE Enviro', '<pad> EXPLORATION POINTS -', '<pad> 2302 Travis St', "<pad> I'm a seasonal", '<pad> The Pareto Faults', '<pad> Enron/Edison', '<pad> 9911 PMA and', '<pad> City of Huntsville', '<pad> Goughary Gasoline Distillate', '<pad> Office of Industrial', "<pad> What's Up?", '<pad> Please help!', '<pad> 4/24/01 load taken', '<pad> Taffy', '<pad> Natural Gas', '<pad> Thanks a lot!', '<pad> Your mailbox is', '<pad> Thank You!', "<pad> What's Up?", '<pad> Happy New Year!', '<pad> mccomb/shitty deer', '<pad> vng sure set', '<pad> e-mail cheat sheet', '<pad> lorraine', '<pad> FOIA/FBI', '<pad> Isda/Enron', '<pad> Kay', '<pad> @MaxDoorReviews', '<pad> psnc invoices', '<pad> Susan Bailey -', '<pad> Meeting Regards', '<pad> ENA/Midwest', '<pad> e-mail cheat sheet', '<pad> Enron JDRF-Walking with', '<pad> Thank You', '<pad> Weekly Summary of', '<pad> TW Marketing, Inc.', '<pad> TEB Rating Outline', '<pad> NEXT WEEK', '<pad> Thursday, November 01,', '<pad> Enron Management Committee', '<pad> FOLLOW-UP', '<pad> Insurance requirements', '<pad> Basics of E-Survey', '<pad> POSREP - HOEGH', "<pad> I'm not sure", '<pad> Consolidation Agreement', '<pad> Enron Savings Plan', '<pad> Questar Sonoran Open', "<pad> Isda's", '<pad> Enron, Inc. ("Enron"),', '<pad> Enron North America,', '<pad> EPMI/Mirant Cuts and', "<pad> What's Up?", '<pad> The Breakfast Club', '<pad> cindy hudler -', '<pad> Thank You', '<pad> Tractebel Energy Marketing', '<pad> M.A.', '<pad> Enron Broadband Notification', '<pad> Oneok Gas Marketing', "<pad> Mary's Counterparty List", '<pad> DBS language comments', '<pad> nepco', '<pad> Picking Draft Order', '<pad> You are a', '<pad> Your Ministry on', '<pad> Enron', "<pad> I'm seeing you!", '<pad> pdrive/terminal server issues', '<pad> Sally CA', '<pad> How are you?', '<pad> AFUDC', '<pad> Enron', '<pad> reorganized Executive Summary', '< ...
# References: ['gisb with tenn. gas status  implementing gisb with tenn gas final execution  re: gisb with tenn. gas Tennessee Gas Pipeling GISB', 'freeze destruction of electronic mail  bid/ask litigation request  please freeze destruction of e-mails Request for Freeze on E-Mail Destruction', 'call me for annex a  request for contact regarding the annex a mail out.  please call regarding annex a mail-out Annex A Letter', 'reminder on update of email domains effective 1/18  deadline: email domains will be no longer available  email domains to be decommissioned UPDATE: Supported Internet Email Addresses', 'attached: guaranty for approval  please approve guaranty  attached guaranty. Enron Corp. Guaranty', "compaq's analyst reports  important file, please read  read the following that tracks copmpaq's performance Financial Analysts' Reports for 6.05.01", 'joining a trading team  seeking junior trader position  farewell for now Good bye! from George Huan', 'referral of calls  callers using false identities  refer calls to public relations Solicitation Calls', 'just getting back to you.  got message - will be in chicago soon  thank you, i will see you soon. Welcome to Chicago and ENA', 'hi, hope all is well!  update on london details  hello from london London', "10/5 meeting agenda attached; deadline to add items is 3 p.m. tomorrow  here's the first draft of the icap working group meeting agenda on 10/5  nyiso_tech_exchange discussion list Draft ICAP WG AGENDA FOR OCt. 5", "david endicott's review needed for non-disclosure agreement  proposed non-disclosure agreement for review  comments please: nda draft + changes NDA-Sabre Corporation", 'instructions for documents  new data copying instructions  cheat sheet for data copy YOU HAVE 48 HOURS - Message from Louise Kitchen', 'pwr-gas-lt-mgmt-prc book  pwr-gas-lt-mgmt-prc book  pwr-gas-lt-mgmt-prc book PWR-GAS-LT-MGMT-PRC', 'important:  fire drill  information regarding the fire drill scheduled for the enron center campus required by the houston fire department.  fire drill scheduled for enron center campus on thursday december 20th Fire Drill Scheduled', 'your businesses remain in egm  your businesses remain in egm  businesses to remain in egm reorg.', 'enron industrial markets metal bulletin  business highlights re enron industrial markets metal bulletin  enron business highlights EnTouch Newsletter', 'bu otcs and devise plans  document plan formatting  hr vp presentation PRC Presentation', 'thoughts and encouragement from loyal employee  words of encouragement  encouragement and confidence from a new employee Vote of Confidence', 'jan. 16 deals.  questions about entries for 1/16  some pertinent questions re: your jan. 16 deals Los Angeles Department of Water and Power IS NOT LADWPPX', 'please advise of company situation, employees concerned  your a/a associates seek reassurance regarding recent news  requesting clarification about recent announcement Information', 'scheduled call time  bowen set time  appointment with bowen confirmation and other details Good News--Twice!', "time to transition to responsible energy  requesting your support calif energy policy  support for panel to evaluate california's energy policy Calif energy panle/ new energy policy for US", 'questioning about counterparties  clarfication re: counterparty trade  london approval of non us & canadian based products Amerada-Hess Corporation', 'consumer presentations for reference  attached short presentation regarding products  blend and extend product presentation Blend & Extend', 'presentation review  presentation review  upcoming meetings Ship Channel Hub Co', 'reschedule for 9 am (11 am sao paulo) fri sept 17  reschedule details  no response from assistant... rescheduled phone call', 'latest marketing list  latest copy of the marketing list  updated marketing list Latest Marketing List', 'technology information for enron center south  orientation to your environment and future technology  enron center south welco ...
# ROUGE Scores:
# ROUGE-1 (Recall): {'r': 0.03154395912506345, 'p': 0.1230383973288815, 'f': 0.049056511984150286}
# ROUGE-2 (Recall): {'r': 0.005602954653821968, 'p': 0.0333889816360601, 'f': 0.009468168063049351}
# ROUGE-L (Recall): {'r': 0.030224434359121283, 'p': 0.11775180856983863, 'f': 0.04697395998143783}

# %%
all_rouge_scores = {'rouge1': [], 'rouge2': [], 'rougeL': []}

# %%
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# %%
for i in range(len(references)):
    scores = scorer.score(hypotheses[i], references[i])
    for key in all_rouge_scores.keys():
        all_rouge_scores[key].append(scores[key].fmeasure)

avg_rouge_scores = {key: sum(scores)/len(scores) for key, scores in all_rouge_scores.items()}
print("Average ROUGE Scores:", avg_rouge_scores)
# Out:
# Average ROUGE Scores: {'rouge1': 0.09854145990184596, 'rouge2': 0.0352832679043674, 'rougeL': 0.09585275417346639}
